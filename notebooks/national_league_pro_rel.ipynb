# %%
import pandas as pd
import numpy as np
import requests

# %%
url = 'https://www.nonleaguematters.co.uk/divisions/1/'

header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

regex = ['Home', 'Away', 'W', 'D', 'L', 'F', 'A', 'GD']

r = requests.get(url, headers=header)

# %%
df = pd.read_html(r.text)[1]

df.columns = df.columns.to_flat_index()
for r in regex:
    df = df[df.columns.drop(list(df.filter(regex=r)))]
df = df.set_axis(['Pos', 'Team', 'Pld', 'Pts'], axis=1, inplace=False)
df = df.drop(['Pos'], axis=1)
df = df[df['Pld'].apply(lambda x: str(x).isdigit())]

# %%
i = np.arange(1,25,1)
df = df.set_index(i)

df
# Out:
#                     Team  Pld  Pts
# 1         Solihull Moors    1    3
# 2           Notts County    1    3
# 3                 Barnet    1    3
# 4              York City    1    3
# 5             Wealdstone    1    3
# 6      Scunthorpe United    1    3
# 7                Wrexham    1    3
# 8           Boreham Wood    1    3
# 9           Chesterfield    1    1
# 10  Dagenham & Redbridge    1    1
# 11     Dorking Wanderers    1    1
# 12             Gateshead    1    1
# 13            Altrincham    1    1
# 14      Maidstone United    1    1
# 15       Oldham Athletic    1    1
# 16        Torquay United    1    1
# 17               Bromley    1    0
# 18             Eastleigh    1    0
# 19           Yeovil Town    1    0
# 20       Southend United    1    0
# 21       FC Halifax Town    1    0
# 22                Woking    1    0
# 23        Aldershot Town    1    0
# 24     Maidenhead United    1    0

# %%
print("Promoted Clubs: ")
print(df['Team'][1])
print()
print("Promotion Playoff Clubs: ")
print(df['Team'][2])
print(df['Team'][3])
print(df['Team'][4])
print(df['Team'][5])
print(df['Team'][6])
print(df['Team'][7])
# Out:
# Promoted Clubs:
# Solihull Moors
#
# Promotion Playoff Clubs:
# Notts County
# Barnet
# York City
# Wealdstone
# Scunthorpe United
# Wrexham

# %%
print("Relegated Clubs: ")
print(df['Team'][21])
print(df['Team'][22])
print(df['Team'][23])
print(df['Team'][24])
# Out:
# Relegated Clubs:
# FC Halifax Town
# Woking
# Aldershot Town
# Maidenhead United
